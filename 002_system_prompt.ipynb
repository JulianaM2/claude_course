# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()
client = Anthropic()
model = "claude-opus-4-8"

# %%
# Helper functions

def add_user_message(messages, text):
    user_message = {
        "role": "user",
        "content": text
    }

    messages.append(user_message)

def add_assistant_message(messages, text):
    assistant_message = {
        "role": "assistant",
        "content": text
    }

    messages.append(assistant_message)

def chat(messages, system=None):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
    }

    if(system is not None):
        params["system"] = system

    message = client.messages.create(**params)

    return message.content[0].text

# %%
messages = []
system="""
You are a patient math tutor.
Do not directly answer a student's questions.
Guide them to a solution step by step.
"""
add_user_message(messages, "How do I solve 5x + 3 = 2 for x?")
answer = chat(messages, system)

answer
# Out:
# '# Solving 5x + 3 = 2 for x\n\n## Step 1: Subtract 3 from both sides\nTo isolate the term with *x*, remove the +3 from the left side.\n\n$$5x + 3 - 3 = 2 - 3$$\n\n$$5x = -1$$\n\n## Step 2: Divide both sides by 5\nTo get *x* by itself, divide by the coefficient (5).\n\n$$\\frac{5x}{5} = \\frac{-1}{5}$$\n\n$$x = -\\frac{1}{5}$$\n\n## Answer\n$$x = -\\frac{1}{5} = -0.2$$\n\n## Check your work\nSubstitute back into the original equation:\n$$5\\left(-\\frac{1}{5}\\right) + 3 = -1 + 3 = 2 ✓$$\n\nIt works! The key idea is to **undo operations in reverse order**—first handle the addition, then the multiplication.'
